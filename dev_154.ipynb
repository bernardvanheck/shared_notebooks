# %%
# %run -i 'ABS_model_and_fitting_functions.ipynb'

# %%
an_full = prepare_data("data_npy/154_dd.npy", 0, 0, chop=False)
lc_full = prepare_data("data_npy/154.npy", 0, 0, chop=False)

# %%
an = prepare_data("data_npy/154_dd.npy", 0, 40)
lc = prepare_data("data_npy/154.npy", 7, 38)
# Sign of abs part is inverted
an['z'] *= -1
calibration_phase_axis(an, lc, 2, 12, 42, 47, plot=False)
plot_datascan(lc)
plot_datascan(an)

# %%
lc_line = peak_positions(lc)
abs_line = peak_positions(an)
# This leaves some spurious points close to flux = 0 and flux = 1 for the ABS line
plt.plot(an['y'][:26], abs_line[:26], 'x')
plt.plot(lc['y'], lc_line, 'x')
